# %%
import librosa
import numpy as np
from silero_vad import load_silero_vad, get_speech_timestamps

# %%
PATHS = [
    r"C:\Users\Admin\Desktop\ip\Automatic Speech Recognition\audio\audio2.wav", 
    r"C:\Users\Admin\Desktop\ip\Automatic Speech Recognition\audio\audio3.wav", 
    r"C:\Users\Admin\Desktop\ip\Automatic Speech Recognition\audio\audio4.wav",
    r"C:\Users\Admin\Desktop\ip\Automatic Speech Recognition\audio\audio5.wav",
    r"C:\Users\Admin\Desktop\ip\Automatic Speech Recognition\audio\audio6.wav",
    r"C:\Users\Admin\Desktop\ip\Automatic Speech Recognition\audio\audio7.wav",
    r"C:\Users\Admin\Desktop\ip\Automatic Speech Recognition\audio\audio8.wav",
    r"C:\Users\Admin\Desktop\ip\Automatic Speech Recognition\audio\audio9.wav"
    ]


SPECS = {
    "sample_rate": 16000,
    "mono": True
}

"""
Load Model Voice Activity Detector
"""

VAD_MODEL = load_silero_vad ()


for alpha in PATHS:

    WAV, SAMPLE_RATE = librosa.load (alpha, sr = SPECS["sample_rate"], mono = SPECS["mono"])

    """
    ÁUDIO STATS
    """

    FORMATO = WAV.shape
    DURATION = FORMATO[0] / SPECS["sample_rate"]
    AMPLITUDE_MAX = np.max (np.abs (WAV)) #abs converte tudo para números > 0

    ROOT_MEAN_SQUARE = np.sqrt (np.mean (WAV ** 2))  

    """
    VAD
    """

    WAV_TIMESTAMPS = get_speech_timestamps (WAV, VAD_MODEL, return_seconds = True)

    TIME_SPEAKING = 0

    for alpha in WAV_TIMESTAMPS:

        TIME_SPEAKING += alpha["end"] - alpha["start"]

    SILENCE = (DURATION - TIME_SPEAKING) / DURATION * 100 

    print (f"Formato do Áudio: {FORMATO}")
    print (f"Duração do Áudio: {DURATION:.1f}s")
    print (f"Amplitude Máxima do Áudio: {AMPLITUDE_MAX:.2f}")
    print (f"Média da Amplitude: {ROOT_MEAN_SQUARE:.2f}")
    print (f"Percentagem de Silêncio no Áudio: {SILENCE:.0f}%\n-----------------------")
# Out:
# Formato do Áudio: (384151,)
# Duração do Áudio: 24.0s
# Amplitude Máxima do Áudio: 0.61
# Média da Amplitude: 0.13
# Percentagem de Silêncio no Áudio: 13%
# -----------------------
# Formato do Áudio: (416102,)
# Duração do Áudio: 26.0s
# Amplitude Máxima do Áudio: 1.01
# Média da Amplitude: 0.23
# Percentagem de Silêncio no Áudio: 8%
# -----------------------
# Formato do Áudio: (866836,)
# Duração do Áudio: 54.2s
# Amplitude Máxima do Áudio: 0.99
# Média da Amplitude: 0.20
# Percentagem de Silêncio no Áudio: 10%
# -----------------------
# Formato do Áudio: (843346,)
# Duração do Áudio: 52.7s
# Amplitude Máxima do Áudio: 0.41
# Média da Amplitude: 0.11
# Percentagem de Silêncio no Áudio: 5%
# -----------------------
# Formato do Áudio: (473165,)
# Duração do Áudio: 29.6s
# Amplitude Máxima do Áudio: 0.65
# Média da Amplitude: 0.16
# Percentagem de Silêncio no Áudio: 13%
# -----------------------
# Formato do Áudio: (714873,)
# Duração do Áudio: 44.7s
# ...

# %% [markdown]
# <hr>

# %%
speech1 = audio[38432:591840]

import soundfile as sf

sf.write ("x.wav", speech1, 16000)

# %%
for x in speech_timestamps[:1]:

    print (x)

# %%
from scipy.signal import butter, sosfilt

sos = butter(
    8,
    120,
    btype = "highpass",
    fs = 16000,
    output = "sos"
)

audio = sosfilt(sos, audio)

# %%
import soundfile as sf


sf.write ("5.wav", audio, 16000)

# %%
from pydub import AudioSegment
from pydub.effects import compress_dynamic_range

audio = AudioSegment.from_wav(r"C:\Users\Admin\Desktop\ip\Automatic Speech Recognition\5.wav")

audio = compress_dynamic_range(
    audio,
    threshold=-35,
    ratio=5,
    attack=5,
    release=50
)

audio.export("enhanced.wav", format="wav")
# Out:
# <_io.BufferedRandom name='enhanced.wav'>
