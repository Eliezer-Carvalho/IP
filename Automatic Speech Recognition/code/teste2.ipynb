# %%
from guidance import system, user, assistant, gen
from guidance.models import Transformers

# %%
model = Transformers (r"C:\Users\Admin\Desktop\models\Language Models\Amália 9B DPO Q8")
# Out:
# W0812 10:01:26.403000 6936 Lib\site-packages\torch\utils\flop_counter.py:29] triton not found; flop counting will not work for triton kernels
# Loading weights:   0%|          | 0/381 [00:00<?, ?it/s]
# c:\Users\Admin\Desktop\ip\Automatic Speech Recognition\.venv\Lib\site-packages\guidance\models\_engine\_tokenizer.py:42: UserWarning: Chat template {% if messages[0]['role'] != 'system' %}{% set messages = [{'role': 'system', 'content': 'O teu nome é Amália, e és um modelo avançado de linguagem útil. Responde sempre na língua do utilizador, a menos que sejas instruído em contrário, e lembra-te que a tua língua principal é o português europeu.'}] + messages %}{% endif %}{% if not add_generation_prompt is defined %}{% set add_generation_prompt = false %}{% endif %}{% for message in messages %}{{ '<|im_start|>' + message['role'] + '
# ' + message['content'] + '<|im_end|>
# ' }}{% endfor %}{% if add_generation_prompt %}{{ '<|im_start|>assistant
# ...

# %%
lm = model

with system ():
    lm += "És um assistente prestável"

with user ():
    lm += "Olá, como te chamas ?"

with assistant ():
    lm += gen (max_tokens = 50)

print(lm)

# %% [markdown]
# <hr>

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

MODEL = r"C:\Users\Admin\Desktop\models\Language Models\Mistral 7B Q4"

model = AutoModelForCausalLM.from_pretrained (MODEL, device_map = "cuda")
tokenizer = AutoTokenizer.from_pretrained (MODEL)
# Out:
# W0812 10:21:02.852000 14972 Lib\site-packages\torch\utils\flop_counter.py:29] triton not found; flop counting will not work for triton kernels
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]

# %%
from transformers import TextStreamer 

inputs = tokenizer ("9 + 9 ?", return_tensors = "pt").to ("cuda")



generate = model.generate (**inputs, tokenizer = tokenizer, max_new_tokens = 50, streamer = TextStreamer (tokenizer))

#print (tokenizer.batch_decode (generate, skip_special_tokens = True)[0])
# Out:
# <s> 9 + 9 ?
#
# 9 + 9 = 18
#
# What is the sum of 9 and 9?
#
# The sum of 9 and 9 is 18.
#
# This is a basic arithmetic operation, and
