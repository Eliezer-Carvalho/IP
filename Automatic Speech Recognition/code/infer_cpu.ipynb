# %%
from subprocess import Popen
from openai import OpenAI
import time
import requests

# %%
CPU = Popen ([
    r"C:\Users\Admin\AppData\Local\Microsoft\WinGet\Packages\ggml.llamacpp_Microsoft.Winget.Source_8wekyb3d8bbwe\llama-server.exe",
    "-m", r"C:\Users\Admin\Desktop\models\Language Models\CPU\Qwen 8B Q4\Qwen 8B Q4.gguf",
    "-c", "200",
    "-ngl", "0",
    "--reasoning", "off",
    "--host", "127.0.0.1",
    "--port", "8080",

    "--no-webui",
])
### --no-jinja é erro de rookie porque o mesmo só aplica chat template, não muda o sistem content



time.sleep (5)

resposta = requests.get ("http://127.0.0.1:8080/health") #https://github.com/ggml-org/llama.cpp/blob/master/tools/server/README.md
print (resposta) #503 - loading | 200 - loaded

API = OpenAI (base_url = "http://127.0.0.1:8080/v1", api_key = "IP2026")

mensagens = [
    {"role": "system", "content": "Olá, teste teste"},
    {"role": "user", "content": "Olá, como estás ?"}
]

output_llama = API.chat.completions.create (model = "x", messages = mensagens, stream = True)

for x in output_llama:
    y = x.choices[0].delta.content

    print (y)

display (output_llama)
CPU.kill ()
# Out:
# <Response [200]>
# [None]
# [None, 'Ol']
# [None, 'Ol', 'á']
# [None, 'Ol', 'á', '!']
# [None, 'Ol', 'á', '!', ' Est']
# [None, 'Ol', 'á', '!', ' Est', 'ou']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por', ' perg']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por', ' perg', 'unt']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por', ' perg', 'unt', 'ar']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por', ' perg', 'unt', 'ar', '.']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por', ' perg', 'unt', 'ar', '.', ' Como']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por', ' perg', 'unt', 'ar', '.', ' Como', ' pos']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por', ' perg', 'unt', 'ar', '.', ' Como', ' pos', 'so']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por', ' perg', 'unt', 'ar', '.', ' Como', ' pos', 'so', ' ajud']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por', ' perg', 'unt', 'ar', '.', ' Como', ' pos', 'so', ' ajud', 'ar']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por', ' perg', 'unt', 'ar', '.', ' Como', ' pos', 'so', ' ajud', 'ar', ' você']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por', ' perg', 'unt', 'ar', '.', ' Como', ' pos', 'so', ' ajud', 'ar', ' você', ' hoje']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por', ' perg', 'unt', 'ar', '.', ' Como', ' pos', 'so', ' ajud', 'ar', ' você', ' hoje', '?']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por', ' perg', 'unt', 'ar', '.', ' Como', ' pos', 'so', ' ajud', 'ar', ' você', ' hoje', '?', ' 😊']
# [None, 'Ol', 'á', '!', ' Est', 'ou', ' bem', ',', ' obrig', 'ado', ' por', ' perg', 'unt', 'ar', '.', ' Como', ' pos', 'so', ' ajud', 'ar', ' você', ' hoje', '?', ' 😊', None]
