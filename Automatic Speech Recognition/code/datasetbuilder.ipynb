# %%
import json
import numpy as np

# %% [markdown]
# <h1> Dataset Ground Truth </h1>

# %%
with open (r"C:\Users\Admin\Desktop\ip\Automatic Speech Recognition\audios.json", "r", encoding = "utf-8") as f:
    json_file = json.load (f)

"""
Tempo de Áudio do Dataset
"""
time = []

for x in json_file:
    #print (x["duration"])
    time.append (int(x["duration"]))

print (sum(time), "s")
print (sum(time) / 60, "min")
print (np.mean (time), "s")
print (len(json_file), "exemplos")
# Out:
# 606 s
# 10.1 min
# 43.285714285714285 s
# 14 exemplos

# %%
"""
from datasets import Dataset, Audio
from pathlib import Path


Outra maneira usando HF Datasets


y = {
    "audio": [],
    "trans": []
}

files = Path (r"C:\Users\Admin\Desktop\ip\Automatic Speech Recognition\audio")

for x in files.iterdir():

    y["audio"].append (str(x))
    y["trans"].append ("xx")

    #display (y)

dataset = Dataset.from_dict (y)

dataset = dataset.cast_column ("audio", Audio (sampling_rate = 16000)) # cast_column altera o tipo/formato de uma coluna do Hugging Face Dataset

print (dataset[0])
"""
