# %%
import pymupdf

# %%
doc = pymupdf.open (r"C:\Users\Admin\Desktop\ip\Automatic Speech Recognition\Automatic Speech Recognition.pdf")

page = doc[2]

# %%
for página in doc:
    print (página.get_contents())
# Out:
# [22]
# [28]
# [32]
# [39]

# %%
tables = page.find_tables()
for table in tables:
    print(table.to_markdown())
# Out:
# Consider using the pymupdf_layout package for a greatly improved page layout analysis.
# |Embeddings|Geração Auto Regressiva|
# |---|---|
# |O output do Encoder, é o input do Decoder|Converte os embeddings para tokens e<br>gera texto|
#
#
# |Tipos de Decoder’s|Vantagens|Limitações|
# |---|---|---|
# |CTC Decoder<br>(Connectionist Temporal<br>Classifcation)|Muito rápido, simples,<br>excelente para streaming|Pouco contexto<br>linguístico e mais erros<br>em frases ambíguas|
# |Attention Decoder|Elevada precisão, melhor<br>contexto|Mais caro e lento, menos<br>adequado para<br>streaming|
# |Transformer Decoder|Excelente precisão, boa<br>performance|Mais caro e lento|
# |RNN-T Decoder|Streaming em tempo real,<br>baixa latência|Específco para sistemas<br>de baixa latência|
#
#
# |Word Error Rate<br>(WER)|Character Error<br>Rate (CER)|Latência|Real Time<br>Factor|
# |---|---|---|---|
# ...
