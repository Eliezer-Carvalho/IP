# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import time
import torch

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print (device)

# %%
MODELO_PATH = r"C:\Users\Admin\Desktop\models\Teste\Qwen3-4B-Base\GPUQ4"

modelo = AutoModelForCausalLM.from_pretrained (MODELO_PATH, device_map = device)

tokenizer = AutoTokenizer.from_pretrained (MODELO_PATH)

# %%
prompt = "O que sabes da empresa Infraestruturas de Portugal ?"

input = tokenizer (prompt, return_tensors = "pt").to(device)

tokens = modelo.generate (**input, max_new_tokens = 500)

print (tokenizer.decode (tokens[0]))

# %% [markdown]
# <h1> Time To First Token </h1>

# %%
TtFT = []

prompt = "A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estat! A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estat!"

input = tokenizer (prompt, return_tensors = "pt").to(device)
input_ids = input["input_ids"]

print (input_ids.shape)

#print (torch.cuda.memory_allocated())
#print (torch.cuda.memory_reserved())


with torch.no_grad():
    for _ in range (5):
        
        torch.cuda.synchronize()
        t0 = time.perf_counter()
        kv_cache = None

        outputs = modelo (**input, past_key_values = kv_cache, use_cache = True)

        #print (torch.cuda.memory_allocated())
        #print (torch.cuda.memory_reserved())

        kv_cache = outputs.past_key_values
        generated = input_ids

        for _ in range (1):
            
            outputs = modelo (input_ids = generated [:, -1:], past_key_values = kv_cache, use_cache = True)

            logits = outputs.logits [:, -1, :]
                
            next_token = torch.argmax (logits, dim = -1, keepdim = True) #explicar

            kv_cache = outputs.past_key_values
            generated = torch.cat ([generated, next_token], dim = 1)
            
            torch.cuda.synchronize()
            t1 = time.perf_counter()

        TtFT.append(t1 - t0)
        #print ("done")
        #print(torch.cuda.memory_summary())

# %%
print (TtFT)

# %%
print(modelo.dtype)
print(next(modelo.parameters()).dtype)
print(input_ids.shape)
print(torch.cuda.get_device_name(0))

# %%
print(torch.__version__)

print(torch.backends.cuda.flash_sdp_enabled())
print(torch.backends.cuda.mem_efficient_sdp_enabled())
print(torch.backends.cuda.math_sdp_enabled())

print(modelo.config._attn_implementation)

# %%
print(modelo.config.num_hidden_layers)
print(modelo.config.hidden_size)
print(modelo.config.num_attention_heads)
print(modelo.config.num_key_value_heads)

# %% [markdown]
# <h1> Latência </h1>

# %%
Lat = []

prompt = "A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estat! A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estat!"


with torch.no_grad():
    for i in range (5):
        
        torch.cuda.synchronize()
        t0 = time.perf_counter()
        input = tokenizer (prompt, return_tensors = "pt").to(device)

        kv_cache = None

        outputs = modelo (**input, use_cache = True)

        kv_cache = outputs.past_key_values
        
        generated = input["input_ids"]

        for k in range (50):

            outputs = modelo (input_ids = generated [:, -1:], past_key_values = kv_cache, use_cache = True)

            logits = outputs.logits [:, -1, :]
                
            next_token = torch.argmax (logits, dim = -1, keepdim = True) #explicar

            kv_cache = outputs.past_key_values
            generated = torch.cat ([generated, next_token], dim = 1)
            
            #print (tokenizer.decode (generated[0]))
        
        torch.cuda.synchronize()
        t1 = time.perf_counter()
        Lat.append(t1 - t0)

# %%
print (Lat)

# %%
print("torch.cuda.memory_allocated: %fGB"%(torch.cuda.memory_allocated(0)/1024/1024/1024))
print("torch.cuda.memory_reserved: %fGB"%(torch.cuda.memory_reserved(0)/1024/1024/1024))
print("torch.cuda.max_memory_reserved: %fGB"%(torch.cuda.max_memory_reserved(0)/1024/1024/1024))

# %% [markdown]
# <h1> Prefill e Decode </h1>

# %%
throughput = {
    "Prefill": [],
    "Decode": []
}

# %%
prompt = "A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estat! A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estat!"

input = tokenizer (prompt, return_tensors = "pt").to(device)

modelo.eval()

#Warmup
for _ in range (3):
    with torch.no_grad():
        _ = modelo (**input)

#Prefill
for _ in range (5):
    torch.cuda.synchronize()
    dt_0 = time.perf_counter() #Time
    with torch.no_grad():
        
        input_tokens = modelo (**input)
        
        torch.cuda.synchronize()
        dt_1 = time.perf_counter() #Time

        throughput["Prefill"].append(dt_1 - dt_0)
        print("torch.cuda.memory_allocated: %fGB"%(torch.cuda.memory_allocated(0)/1024/1024/1024))

# %%
print (throughput["Prefill"])

# %%
prompt = "A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estat! A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estatística. A equipa analisou os registos do sistema durante várias semanas. Foram recolhidos dados sobre utilização de CPU, memória, latência de rede, operações de disco e tempos de resposta das aplicações. Cada observação foi armazenada numa base de dados para posterior análise estat!"

input = tokenizer (prompt, return_tensors = "pt").to(device)

input_ids = input["input_ids"]

#print (input_ids.shape)

modelo.eval()

for _ in range (5):

    kv_cache = None

    with torch.no_grad():
        outputs = modelo (**input, past_key_values = kv_cache, use_cache = True)

    kv_cache = outputs.past_key_values
    generated = input_ids
    
    torch.cuda.synchronize()
    t2 = time.perf_counter()

    with torch.no_grad():
        for i in range (50):

            outputs = modelo (input_ids = generated [:, -1:], past_key_values = kv_cache, use_cache = True)

            logits = outputs.logits [:, -1, :]
                
            next_token = torch.argmax (logits, dim = -1, keepdim = True) #explicar

            kv_cache = outputs.past_key_values
            generated = torch.cat ([generated, next_token], dim = 1)
            
        torch.cuda.synchronize()
        t3 = time.perf_counter()
        throughput["Decode"].append(t3 - t2)
        print ("done")

# %%
print (throughput["Decode"])
