# %%
from datasets import load_datasets

from datasets import get_dataset_split_names

# %% [markdown]
# <h2> Manage de Datasets em Streaming </h2>

# %%
print (get_dataset_split_names("freds0/TAGARELA")) # Para saber os splits que existem

benchmark = load_dataset ("inesc-id/camoes_SI", split = "test", streaming = True)#.take(50) #https://huggingface.co/docs/datasets/stream

print (benchmark)

exemplo = next(iter(benchmark))

print (exemplo.keys())
print (exemplo)

benchmark = benchmark.take(3000) #aponta para um iterável que limita a leitura aos primeiros 3000 exemplos

# %%
dataset = dataset1.filter(lambda x: x["accent"] == "pt-pt")
