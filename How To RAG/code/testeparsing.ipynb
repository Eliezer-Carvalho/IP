# %%
import pymupdf #https://pymupdf.readthedocs.io/en/latest/page.html
import pymupdf4llm

from langchain.text_splitter import MarkdownTextSplitter

# %%
pdf = pymupdf.open (r"C:\Users\Admin\Desktop\ip\How To RAG\docs\Crianças_e_jovens_(9-17)_e_Inteligência_Artificial_Generativa_em_Portugal.pdf")

# %%
# Some stats
print (pdf)

for i in pdf:
    print (i)

# %%
# Alguns métodos

page = pdf [23]

size = page.rect #Tamanho da página atual

origin_size = page.mediabox #Tamanho original da página do PDF #esquerda,zoom,largura, altura

cropbox = page.cropbox #Área Visível

rot = page.rotation #Rotação da página

################

teste = page.get_text ("words")

#teste_2 = page.get_text("blocks")   # blocos (layout)
#teste_3 = page.get_text("dict")     # estrutura completa
#teste_4 = page.get_text("html")     # HTML layout
#teste_5 = page.get_text("json")


imagens = page.get_images (full = True)

#print (imagens)

#img = pdf.extract_image (imagens[0][0])

#page.insert_text((50, 50), "Hello")

'''rotation = page.rotation

cropbox = page.cropbox

media_box = page.mediabox'''

#print (f"{size}\n{origin_size}\n{cropbox}\n{rot}")


display (teste)

#page.set_cropbox (pymupdf.Rect(page.mediabox[0] + 50, page.mediabox[1], page.mediabox[2] - 50, page.mediabox[3] - 50))

#print (f"{rotation}\n{cropbox}\n{media_box}")



'''pict = page.get_pixmap(dpi = 600)
pict.save ("x.png")'''

# %% [markdown]
# <hr>
# <hr>
